# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
def is_outlier(points, thresh=3.5):
    """
    Returns a boolean array with True if points are outliers and False 
    otherwise.

    Parameters:
    -----------
        points : An numobservations by numdimensions array of observations
        thresh : The modified z-score to use as a threshold. Observations with
            a modified z-score (based on the median absolute deviation) greater
            than this value will be classified as outliers.

    Returns:
    --------
        mask : A numobservations-length boolean array.

    References:
    ----------
        Boris Iglewicz and David Hoaglin (1993), "Volume 16: How to Detect and
        Handle Outliers", The ASQC Basic References in Quality Control:
        Statistical Techniques, Edward F. Mykytka, Ph.D., Editor. 
    """
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return modified_z_score > thresh

# %%
train = pd.read_csv(open('train.csv'), sep = ',')
test = pd.read_csv(open('test.csv'), sep = ',')
train.shape, test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
#Scatter plot of Id vs Sale Price
data = train[['Id','SalePrice']].values
#Plot part
plt.scatter(data[:,0],data[:,1]);
plt.xlabel('Id');
plt.ylabel('SalePrice');

# %%
type(train),type(test)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
train.isnull().values.any(),train.isnull().sum().sum()
# Out:
# (True, 6965)

# %%
train.isnull().values.sum().sum()
# Out:
# 6965

# %%
train.shape, test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
#Concat train and test data so as to avoid mismatch of number of features after applying pandas_dataframe.get_dummies
train_test_data = pd.concat((train.loc[:,'MSSubClass':'SaleCondition'],test.loc[:,'MSSubClass':'SaleCondition']))
train_test_data.shape
# Out:
# (2919, 79)

# %% [markdown]
# Categorical caolumns

# %%
categorical_columns = []
for column in train_test_data.columns.values:
    if train_test_data[column].dtype == 'object':
        categorical_columns.append(column)

# %%
train_numerical = train_test_data.drop(categorical_columns, axis=1)
train_categorical = train_test_data[categorical_columns]
train_numerical.shape, train_categorical.shape
# Out:
# ((2919, 36), (2919, 43))

# %% [markdown]
# Numerical data imputation

# %%
from scipy.stats import skew
from sklearn.preprocessing import Normalizer
for column in train_numerical.columns.values:
    if(train_numerical[column].isnull().sum().sum() > 100):
        train_numerical = train_numerical.drop(column, axis = 1)
    elif (train_numerical[column].isnull().sum().sum() > 0):
        train_numerical = train_numerical.fillna(train_numerical[column].median())
    
    outlier = np.where(is_outlier(train_numerical[column]))
    train_numerical[column].iloc[outlier] = train_numerical[column].median()
    
    if skew(train_numerical[column]) > 0.75:
        train_numerical[column] = np.log(train_numerical[column])
        train_numerical[column] = train_numerical[column].apply(lambda x: 0 if x == -np.inf else x)
        
    train_numerical[column] = Normalizer().fit_transform(train_numerical[column].reshape(1,-1))[0]

# %% [markdown]
# Categorical data imputation

# %%
for column in train_categorical.columns.values:
    if(train_categorical[column].isnull().sum().sum() > 100):
        train_categorical = train_categorical.drop(column, axis = 1)
        continue
    elif (train_categorical[column].isnull().sum().sum() > 0):
        train_categorical[column] = train_categorical.fillna(train_categorical[column].value_counts().index[0])

# %%
#Convert categorical variable into dummy/indicator variables
train_categorical = pd.get_dummies(train_categorical)
train_categorical.shape
# Out:
# (2919, 194)

# %%
train_test_data_new = train_numerical.join(train_categorical)
train_test_data_new.shape, train_numerical.shape, train_categorical.shape
# Out:
# ((5837, 229), (2919, 35), (2919, 194))

# %%
train_rows = int(train.shape[0] * 0.8)
val_rows = train.shape[0] - train_rows
train_rows, val_rows
# Out:
# (1168, 292)

# %%
#Train partition
xTrain = train_test_data_new.iloc[:train.shape[0],:]
tTrain = train.loc[:train.shape[0] ,'SalePrice']

"""
xTrain = train_test_data_new.iloc[:train_rows,:]
tTrain = train.loc[:train_rows -1 ,'SalePrice']
"""

"""
#Validation partition
vTrain = train_test_data_new.iloc[train_rows:train.shape[0],:]
vtTrain = train.loc[train_rows:train.shape[0],'SalePrice']
"""


#xTest partition
xTest = train_test_data_new.iloc[train.shape[0]:,:]

# %%
type(tTrain.values)
# Out:
# numpy.ndarray

# %%
tTrain = pd.DataFrame(np.log1p(tTrain.values))

# %%
train_test_data_new.shape, xTrain.shape, tTrain.shape, xTest.shape
# Out:
# ((5837, 229), (1460, 229), (1460, 1), (4377, 229))

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestRegressor
'''
The value of n_estimators is kept high so as to have stability of RandomForest; 
If we take lower values of n_estimotros, we'll observe the variation in importance 
of features calculated next.
'''
clf = RandomForestRegressor(n_estimators=500, n_jobs=-1)
clf = clf.fit(xTrain,tTrain)
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
'''Get names of the features of entire data'''
names = list(train_test_data_new.columns.values)
'''Get the feature importance of RandomForest'''
importances = clf.feature_importances_
#print len(importance)

# %%
'''Map sorted feature importance and names of features'''
print "Features sorted by their score:"
print sorted(zip(map(lambda x: round(x, 4), importances),names), 
             reverse=True)
# Out:
# Features sorted by their score:
# [(0.0652, 'LotArea'), (0.0579, 'BsmtUnfSF'), (0.0538, 'GarageArea'), (0.0513, 'GrLivArea'), (0.0491, '1stFlrSF'), (0.047, 'BsmtFinSF1'), (0.0436, 'TotalBsmtSF'), (0.042, 'MoSold'), (0.0342, 'OpenPorchSF'), (0.033, 'YearRemodAdd'), (0.0311, 'GarageYrBlt'), (0.0296, 'YearBuilt'), (0.0211, 'TotRmsAbvGrd'), (0.0204, 'YrSold'), (0.017, 'OverallQual'), (0.014, 'Fireplaces'), (0.0135, 'MSSubClass'), (0.0087, 'Neighborhood_CollgCr'), (0.0087, 'HouseStyle_SLvl'), (0.0085, 'HeatingQC_Ex'), (0.008, 'Neighborhood_NAmes'), (0.0077, 'LotConfig_Corner'), (0.0076, 'LotConfig_Inside'), (0.0076, 'HouseStyle_1Story'), (0.0075, 'HouseStyle_2Story'), (0.0074, 'HeatingQC_TA'), (0.0073, 'HeatingQC_Gd'), (0.0071, 'LotShape_IR1'), (0.0069, 'ExterCond_Gd'), (0.0067, 'Condition1_PosN'), (0.0066, 'LotShape_Reg'), (0.0066, 'HouseStyle_1.5Fin'), (0.0065, 'ExterCond_TA'), (0.0063, 'ExterQual_TA'), (0.0063, 'ExterQual_Gd'), (0.0061, 'RoofStyle_Gable'), (0.006, 'Neighborhood_Gilbert'), (0.0056, 'Neighborhood_NridgHt'), (0.0056, 'BldgType_1Fam'), (0.0055, 'RoofStyle_Hip'), (0.0055, 'Foundation_PConc'), (0.0054, 'Foundation_CBlock'), (0.0052, 'SaleCondition_Normal'), (0.0052, 'HeatingQC_Fa'), (0.0052, 'Condition1_Norm'), (0.0049, 'Neighborhood_ClearCr'), (0.0048, 'Neighborhood_SawyerW'), (0.0046, 'Neighborhood_BrkSide'), (0.0045, 'Neighborhood_Mitchel'), (0.0045, 'LotConfig_CulDSac'), (0.0044, 'Neighborhood_Edwards'), (0.0043, 'Neighborhood_Timber'), (0.0041, 'Neighborhood_NWAmes'), (0.0041, 'BldgType_Twnhs'), (0.004, 'SaleCondition_Abnorml'), (0.004, 'Neighborhood_OldTown'), (0.004, 'Neighborhood_Blmngtn'), (0.0039, 'SaleCondition_Partial'), (0.0039, 'BldgType_TwnhsE'), (0.0038, 'PavedDrive_P'), (0.0036, 'Neighborhood_Sawyer'), (0.0035, 'LandContour_Lvl'), (0.0035, 'Foundation_Slab'), (0.0033, 'CentralAir_Y'), (0.0031, 'PavedDrive_Y'), (0.003, 'Foundation_BrkTil'), (0.003, 'ExterQual_Ex'), (0.0029, 'Condition1_Artery'), (0.0028, 'CentralAir_N'), (0.0028, 'BldgType_Duplex'), (0.0027, 'Neighborhood_Veenker'), (0.0025, 'RoofStyle_Flat'), (0.0025, 'Neighborhood_SWISU'), (0.0025, 'LandContour_Bnk'), (0.0025, 'HouseStyle_SFoyer'), (0.0023, 'Neighborhood_Crawfor'), (0.0023, 'LotConfig_FR2'), (0.0023, 'Heating_GasA'), (0.0022, 'Condition1_Feedr'), (0.002, 'PavedDrive_N'), (0.002, 'Neighborhood_BrDale'), (0.002, 'LandSlope_Gtl'), (0.0019, 'Condition1_RRAn'), (0.0018, 'Neighborhood_Somerst'), (0.0018, 'Neighborhood_NoRidge'), (0.0018, 'Heating_GasW'), (0.0015, 'LandSlope_Mod'), (0.0014, 'RoofMatl_Tar&Grv'), (0.0014, 'Neighborhood_StoneBr'), (0.0014, 'LandContour_HLS'), (0.0013, 'RoofMatl_CompShg'), (0.0013, 'HouseStyle_1.5Unf'), (0.0012, 'Neighborhood_IDOTRR'), (0.0012, 'ExterCond_Fa'), (0.0012, 'Condition2_Norm'), (0.0011, 'LotShape_IR3'), (0.0011, 'LotShape_IR2'), (0.0011, 'LandContour_Low'), (0.001, 'Condition1_RRAe'), (0.0008, 'SaleType_RL'), (0.0008, 'RoofMatl_WdShake'), (0.0008, 'MasVnrType_RL'), (0.0008, 'MSZoning_RL'), (0.0008, 'LotConfig_FR3'), (0.0008, 'Heating_Grav'), (0.0008, 'Functional_RL'), (0.0008, 'Exterior2nd_RL'), (0.0008, 'Exterior1st_RL'), (0.0008, 'BsmtQual_RL'), (0.0008, 'BsmtFinType2_RL'), (0.0008, 'BsmtExposure_RL'), (0.0007, 'SaleType_RM'), (0.0007, 'SaleType_FV'), (0.0007, 'KitchenQual_RL'), (0.0007, 'HouseStyle_2.5Unf'), (0.0007, 'Functional_RM'), (0.0007, 'Electrical_RL'), (0.0007, 'Condition2_PosN'), (0.0007, 'BsmtCond_RL'), (0.0006, 'Utilities_RM'), (0.0006, 'Utilities_RL'), (0.0006, 'SaleCondition_Family'), (0.0006, 'Neighborhood_NPkVill'), (0.0006, 'MSZoning_RM'), (0.0006, 'KitchenQual_RM'), (0.0006, 'KitchenQual_FV'), (0.0006, 'Foundation_Stone'), (0.0006, 'Exterior2nd_RM'), (0.0006, 'Exterior2nd_FV'), (0.0006, 'Exterior1st_RM'), (0.0006, 'Electrical_RM'), (0.0006, 'Condition1_RRNn'), (0.0006, 'BsmtQual_FV'), (0.0006, 'BsmtFinType1_RM'), (0.0006, 'BsmtFinType1_RL'), (0.0006, 'BsmtExposure_RM'), (0.0006, 'BsmtCond_RM'), (0.0006, 'BldgType_2fmCon'), (0.0005, 'Utilities_FV'), (0.0005, 'SaleCondition_Alloca'), (0.0005, 'Neighborhood_MeadowV ...

# %%
sorted_importances = pd.Series(importances, index = train_test_data_new.columns).sort_values(ascending=False)
sorted_importances = pd.Series(sorted_importances)
plt.figure(figsize=(10, 5))
sorted_importances.head(25).plot(kind='bar')
plt.title('Feature Significance')
plt.tight_layout()

# %%
'''Validation'''
val_prediction = clf.predict(vTrain)
val_prediction.shape
vtTrain_actual = vtTrain.to_frame().loc[:,'SalePrice'].values
len(vtTrain_actual), len(val_prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-d3770214f9a2> in <module>()
#       1 '''Validation'''
# ----> 2 val_prediction = clf.predict(vTrain)
#       3 val_prediction.shape
#       4 vtTrain_actual = vtTrain.to_frame().loc[:,'SalePrice'].values
#       5 len(vtTrain_actual), len(val_prediction)
#
# NameError: name 'vTrain' is not defined

# %%
from sklearn.cross_validation import train_test_split

X_train1, X_test1, y_train1, y_test1 = train_test_split(xTrain, tTrain)
clf = RandomForestRegressor(n_estimators=500, n_jobs=-1)

clf.fit(X_train1, y_train1)
y_pred = clf.predict(X_test1)

plt.figure(figsize=(10, 5))
plt.scatter(y_test1, y_pred, s=20)
plt.title('Predicted vs. Actual')
plt.xlabel('Actual Sale Price')
plt.ylabel('Predicted Sale Price')

plt.plot([min(y_test1), max(y_test1)], [min(y_test1), max(y_test1)])
plt.tight_layout()
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
print "Accuracy", sqrt(mean_squared_error(y_pred, y_test1, multioutput='raw_values'))
# Out:
# Accuracy 0.417911037856

# %%
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.cross_validation import cross_val_score

scorer = make_scorer(mean_squared_error, False)

clf = RandomForestRegressor(n_estimators=500, n_jobs=-1)
cv_score = np.sqrt(-cross_val_score(estimator=clf, X=xTrain, y=tTrain, cv=15, scoring = scorer))

plt.figure(figsize=(10,5))
plt.bar(range(len(cv_score)), cv_score)
plt.title('Cross Validation Score')
plt.ylabel('RMSE')
plt.xlabel('Iteration')

plt.plot(range(len(cv_score) + 1), [cv_score.mean()] * (len(cv_score) + 1))
plt.tight_layout()
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
