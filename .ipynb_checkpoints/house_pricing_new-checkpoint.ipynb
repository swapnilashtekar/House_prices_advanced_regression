# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
def is_outlier(points, thresh=3.5):
    """
    Returns a boolean array with True if points are outliers and False 
    otherwise.

    Parameters:
    -----------
        points : An numobservations by numdimensions array of observations
        thresh : The modified z-score to use as a threshold. Observations with
            a modified z-score (based on the median absolute deviation) greater
            than this value will be classified as outliers.

    Returns:
    --------
        mask : A numobservations-length boolean array.

    References:
    ----------
        Boris Iglewicz and David Hoaglin (1993), "Volume 16: How to Detect and
        Handle Outliers", The ASQC Basic References in Quality Control:
        Statistical Techniques, Edward F. Mykytka, Ph.D., Editor. 
    """
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return modified_z_score > thresh

# %%
train = pd.read_csv(open('train.csv'), sep = ',')
test = pd.read_csv(open('test.csv'), sep = ',')
train.shape, test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
#Scatter plot of Id vs Sale Price
data = train[['Id','SalePrice']].values
#Plot part
plt.scatter(data[:,0],data[:,1]);
plt.xlabel('Id');
plt.ylabel('SalePrice');

# %%
type(train),type(test)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
train.isnull().values.any(),train.isnull().sum().sum()
# Out:
# (True, 6965)

# %%
train.isnull().values.sum().sum()
# Out:
# 6965

# %%
train.shape, test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
#Concat train and test data so as to avoid mismatch of number of features after applying pandas_dataframe.get_dummies
train_test_data = pd.concat((train.loc[:,'MSSubClass':'SaleCondition'],test.loc[:,'MSSubClass':'SaleCondition']))
train_test_data.shape
# Out:
# (2919, 79)

# %% [markdown]
# Categorical caolumns

# %%
categorical_columns = []
for column in train_test_data.columns.values:
    if train_test_data[column].dtype == 'object':
        categorical_columns.append(column)

# %%
train_numerical = train_test_data.drop(categorical_columns, axis=1)
train_categorical = train_test_data[categorical_columns]
train_numerical.shape, train_categorical.shape
# Out:
# ((2919, 36), (2919, 43))

# %% [markdown]
# Numerical data imputation

# %%
from scipy.stats import skew
for column in train_numerical.columns.values:
    if(train_numerical[column].isnull().sum().sum() > 100):
        train_numerical = train_numerical.drop(column, axis = 1)
    elif (train_numerical[column].isnull().sum().sum() > 0):
        train_numerical = train_numerical.fillna(train_numerical[column].median())
    
    outlier = np.where(is_outlier(train_numerical[column]))
    train_numerical[column].iloc[outlier] = train_numerical[column].median()
    
    '''
    if skew(xTrain[column]) > 0.75 :
        
    '''

# %% [markdown]
# Categorical data imputation

# %%
for column in train_categorical.columns.values:
    if(train_categorical[column].isnull().sum().sum() > 100):
        train_categorical = train_categorical.drop(column, axis = 1)
        continue
    elif (train_categorical[column].isnull().sum().sum() > 0):
        train_categorical[column] = train_categorical.fillna(train_categorical[column].value_counts().index[0])
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#Convert categorical variable into dummy/indicator variables
train_categorical = pd.get_dummies(train_categorical)
train_categorical.shape
# Out:
# (2919, 194)

# %%
train_test_data_new = train_numerical.join(train_categorical)
train_test_data_new.shape, train_numerical.shape, train_categorical.shape
# Out:
# ((5837, 229), (2919, 35), (2919, 194))

# %%
train_rows = int(train.shape[0] * 0.8)
val_rows = train.shape[0] - train_rows
train_rows, val_rows
# Out:
# (1168, 292)

# %%
#Train partition
xTrain = train_test_data_new.iloc[:train_rows,:]
tTrain = train.loc[:train_rows -1 ,'SalePrice']

#Validation partition
vTrain = train_test_data_new.iloc[train_rows:train.shape[0],:]
vtTrain = train.loc[train_rows:train.shape[0],'SalePrice']

#xTest partition
xTest = train_test_data_new.iloc[train.shape[0]:,:]

# %%
train_test_data_new.shape, xTrain.shape, tTrain.shape, vTrain.shape, vtTrain.shape, xTest.shape
# Out:
# ((5837, 229), (1168, 229), (1168,), (292, 229), (292,), (4377, 229))

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestRegressor
'''
The value of n_estimators is kept high so as to have stability of RandomForest; 
If we take lower values of n_estimotros, we'll observe the variation in importance 
of features calculated next.
'''
clf = RandomForestRegressor(n_estimators=500)
clf = clf.fit(xTrain,tTrain)

# %%
'''Get names of the features of entire data'''
names = list(train_test_data.columns.values)
'''Get the feature importance of RandomForest'''
importances = clf.feature_importances_
#print len(importance)

# %%
train_new = train_numerical.join(train_categorical)
xTrain = train_new.iloc[:len(train_test_data) - 1]
xTrain.shape
# Out:
# (1459, 274)

# %%
test_columns = train_new.iloc[len(train_test_data) + 1:]
xTest = test_columns[test_columns.columns.values[1:]]

# %%
xTest.shape, xTrain.shape, tTrain.shape
# Out:
# ((0, 273), (1459, 274), (1168,))

# %%
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
train_rows = int(train.shape[0] * 0.8)
val_rows = train.shape[0] - train_rows
train_rows, val_rows
# Out:
# (1168, 292)

# %%
#train_test_data.iloc[:train_rows,:]

# %%
#Train partition
xTrain = train_test_data.iloc[:train_rows,:]
tTrain = train.loc[:train_rows -1 ,'SalePrice']

#Validation partition
vTrain = train_test_data.iloc[train_rows:train.shape[0],:]
vtTrain = train.loc[train_rows:train.shape[0],'SalePrice']

#xTest partition
xTest = train_test_data.iloc[train.shape[0]:,:]

# %%
train_test_data.shape, xTrain.shape, tTrain.shape, vTrain.shape, vtTrain.shape, xTest.shape
# Out:
# ((2919, 288), (1168, 288), (1168,), (292, 288), (292,), (1459, 288))

# %% [markdown]
# for column in xTrain.columns.values:
#     print column

# %%
xTrain.shape
# Out:
# (1168, 287)

# %% [markdown]
# '''[Need to rethink on imputation]'''
#
# # Train :filling NA's with the mean of the column
# xTrain = xTrain.fillna(xTrain.mean())
# tTrain = tTrain.fillna(tTrain.mean())
#
# # Validation :filling NA's with the mean of the column
# vTrain = vTrain.fillna(vTrain.mean())
# vtTrain = vtTrain.fillna(vtTrain.mean())
#
#
#
# #Test : filling NA's with the mean of the column:
# xTest = xTest.fillna(xTest.mean())

# %%
# Out:
# True

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestRegressor
'''
The value of n_estimators is kept high so as to have stability of RandomForest; 
If we take lower values of n_estimotros, we'll observe the variation in importance 
of features calculated next.
'''
clf = RandomForestRegressor(n_estimators=500)
clf = clf.fit(xTrain,tTrain)

# %%
'''Get names of the features of entire data'''
names = list(train_test_data.columns.values)
'''Get the feature importance of RandomForest'''
importances = clf.feature_importances_
#print len(importance)

# %%
'''Map sorted feature importance and names of features'''
print "Features sorted by their score:"
print sorted(zip(map(lambda x: round(x, 4), importances),names), 
             reverse=True)
# Out:
# Features sorted by their score:
# [(0.5704, 'OverallQual'), (0.1241, 'GrLivArea'), (0.0392, 'TotalBsmtSF'), (0.032, 'BsmtFinSF1'), (0.023, '1stFlrSF'), (0.0203, 'GarageCars'), (0.0149, 'GarageArea'), (0.0139, 'LotArea'), (0.0112, 'YearBuilt'), (0.0112, '2ndFlrSF'), (0.0106, 'TotRmsAbvGrd'), (0.0078, 'YearRemodAdd'), (0.007, 'MoSold'), (0.0067, 'FullBath'), (0.0063, 'MasVnrArea'), (0.0057, 'LotFrontage'), (0.005, 'GarageYrBlt'), (0.005, 'BsmtQual_Ex'), (0.0048, 'OpenPorchSF'), (0.0047, 'BsmtUnfSF'), (0.0044, 'OverallCond'), (0.0042, 'WoodDeckSF'), (0.0032, 'Fireplaces'), (0.0028, 'KitchenQual_Gd'), (0.0023, 'BsmtQual_Gd'), (0.0021, 'GarageType_Attchd'), (0.0018, 'ExterQual_Ex'), (0.0016, 'YrSold'), (0.0016, 'MSSubClass'), (0.0015, 'BedroomAbvGr'), (0.0014, 'LotShape_Reg'), (0.0013, 'GarageType_Detchd'), (0.0012, 'ScreenPorch'), (0.0012, 'CentralAir_N'), (0.0011, 'MSZoning_RM'), (0.0011, 'KitchenQual_TA'), (0.0011, 'ExterQual_Gd'), (0.0011, 'CentralAir_Y'), (0.0011, 'BsmtExposure_Gd'), (0.001, 'KitchenQual_Ex'), (0.001, 'HalfBath'), (0.001, 'BsmtFullBath'), (0.0009, 'LotShape_IR2'), (0.0008, 'Exterior2nd_HdBoard'), (0.0008, 'BsmtHalfBath'), (0.0008, 'BsmtExposure_No'), (0.0007, 'MasVnrType_Stone'), (0.0007, 'ExterQual_TA'), (0.0007, 'EnclosedPorch'), (0.0007, 'BsmtFinType1_GLQ'), (0.0006, 'SaleCondition_Partial'), (0.0006, 'RoofStyle_Hip'), (0.0006, 'MSZoning_RL'), (0.0006, 'GarageFinish_Unf'), (0.0006, 'GarageFinish_Fin'), (0.0006, 'FireplaceQu_Gd'), (0.0006, 'BsmtFinSF2'), (0.0005, 'SaleType_WD'), (0.0005, 'SaleType_New'), (0.0005, 'SaleCondition_Normal'), (0.0005, 'Neighborhood_StoneBr'), (0.0005, 'Neighborhood_Crawfor'), (0.0005, 'MasVnrType_BrkFace'), (0.0005, 'GarageFinish_RFn'), (0.0005, 'Exterior2nd_VinylSd'), (0.0005, 'Exterior1st_VinylSd'), (0.0005, 'Exterior1st_HdBoard'), (0.0005, 'Condition1_PosN'), (0.0004, 'SaleCondition_Family'), (0.0004, 'RoofStyle_Gable'), (0.0004, 'RoofMatl_WdShngl'), (0.0004, 'MSZoning_C (all)'), (0.0004, 'LotShape_IR1'), (0.0004, 'LotConfig_Inside'), (0.0004, 'LotConfig_CulDSac'), (0.0004, 'LandContour_Lvl'), (0.0004, 'LandContour_Bnk'), (0.0004, 'KitchenAbvGr'), (0.0004, 'GarageQual_TA'), (0.0004, 'Functional_Typ'), (0.0004, 'Condition1_Norm'), (0.0004, 'BsmtQual_TA'), (0.0004, 'BsmtFinType1_ALQ'), (0.0003, 'SaleCondition_Abnorml'), (0.0003, 'PavedDrive_N'), (0.0003, 'Neighborhood_NridgHt'), (0.0003, 'Neighborhood_NoRidge'), (0.0003, 'Neighborhood_Edwards'), (0.0003, 'Neighborhood_CollgCr'), (0.0003, 'MasVnrType_None'), (0.0003, 'LotConfig_Corner'), (0.0003, 'LandSlope_Gtl'), (0.0003, 'HeatingQC_TA'), (0.0003, 'HeatingQC_Ex'), (0.0003, 'FireplaceQu_Ex'), (0.0003, 'ExterCond_Fa'), (0.0002, 'RoofMatl_CompShg'), (0.0002, 'PavedDrive_Y'), (0.0002, 'Neighborhood_Timber'), (0.0002, 'Neighborhood_Somerst'), (0.0002, 'Neighborhood_NAmes'), (0.0002, 'Neighborhood_ClearCr'), (0.0002, 'LandSlope_Mod'), (0.0002, 'LandContour_Low'), (0.0002, 'LandContour_HLS'), (0.0002, 'HouseStyle_2Story'), (0.0002, 'HouseStyle_1Story'), (0.0002, 'HouseStyle_1.5Fin'), (0.0002, 'HeatingQC_Gd'), (0.0002, 'GarageType_BuiltIn'), (0.0002, 'Functional_Mod'), (0.0002, 'Foundation_PConc'), (0.0002, 'Foundation_CBlock'), (0.0002, 'FireplaceQu_TA'), (0.0002, 'Exterior2nd_Plywood'), (0.0002, 'Exterior2nd_MetalSd'), (0.0002, 'Exterior2nd_CmentBd'), (0.0002, 'Exterior2nd_BrkFace'), (0.0002, 'Exterior1st_MetalSd'), (0.0002, 'Exterior1st_BrkFace'), (0.0002, 'ExterCond_TA'), (0.0002, 'Condition2_PosN'), (0.0002, 'BsmtFinType1_Unf'), (0.0002, 'BsmtExposure_Av'), (0.0002, 'BsmtCond_Gd'), (0.0002, 'BldgType_1Fam'), (0.0001, 'SaleType_COD'), (0.0001, 'RoofStyle_Flat'), (0.0001, 'PavedDrive_P'), (0.0001, 'Neighborhood_SawyerW'), (0.0001, 'Neighborhood_Sawyer'), (0.0001, 'Neighborhood_OldTown'), (0.0001, 'Neighborhood_NWAmes'), (0.0001, 'Neighborhood_IDOTRR'), (0.0001, 'Neighborhood_Gilbert'), (0.0001, 'Neighborhood_BrkSide'), (0.0001, 'MiscVal'), (0.0001, 'MSZoning_FV'), (0.0001, 'LowQualFinSF'), (0.0001, 'LotConfig_FR2'), (0.0001, 'KitchenQual_Fa'), (0.0001, 'GarageCond_TA ...

# %%
sorted_importances = pd.Series(clf.feature_importances_, index = train_test_data.columns).sort_values(ascending=False)
sorted_importances = pd.Series(sorted_importances)
plt.figure(figsize=(10, 5))
sorted_importances.head(25).plot(kind='bar')
plt.title('Feature Significance')
plt.tight_layout()

# %%
'''Plot feature names vs feature importance importances = clf.feature_importances_'''

indices = np.argsort(importances)[::-1]

'''Print the feature ranking'''
print("Feature ranking:")

'''
for f in range(xTrain.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

for f in range(xTrain.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
'''

'''Plot the feature importances of the forest'''
plt.figure()
plt.title("Feature importances")
plt.bar(range(xTrain.shape[1]), importances[indices],
       color="b", align="center")
plt.xticks(range(xTrain.shape[1]), indices)
plt.xlim([-1, xTrain.shape[1]*0.05])
plt.show()
# Out:
# Feature ranking:

# %%
'''Validation'''
val_prediction = clf.predict(vTrain)
val_prediction.shape
# Out:
# (292,)

# %%
vtTrain_actual = vtTrain.to_frame().loc[:,'SalePrice'].values
len(vtTrain_actual), len(val_prediction)
# Out:
# (292, 292)

# %%
type(vtTrain_actual), type(val_prediction)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
vtTrain_actual.shape, val_prediction.shape
# Out:
# ((292,), (292,))

# %%
plt.figure(figsize=(10, 5))
plt.scatter(vtTrain_actual, val_prediction, s=20)
plt.title('Predicted vs. Actual')
plt.xlabel('Actual Sale Price')
plt.ylabel('Predicted Sale Price')

plt.plot([min(vtTrain_actual), max(vtTrain_actual)], [min(vtTrain_actual), max(vtTrain_actual)])
plt.tight_layout()

# %%
'''Accuracy score'''
'''
from sklearn.metrics import accuracy_score
print "Accuracy", accuracy_score(vtTrain_actual, val_prediction)
'''
# Out:
# '\nfrom sklearn.metrics import accuracy_score\nprint "Accuracy", accuracy_score(vtTrain_actual, val_prediction)\n'

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
print "Accuracy", sqrt(mean_squared_error(val_prediction, vtTrain_actual, multioutput='raw_values'))
# Out:
# Accuracy 35838.3898294

# %%
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.cross_validation import cross_val_score

scorer = make_scorer(mean_squared_error, False)

clf = RandomForestRegressor(n_estimators=500, n_jobs=-1)
cv_score = np.sqrt(-cross_val_score(estimator=clf, X=xTrain, y=tTrain, cv=15, scoring = scorer))

plt.figure(figsize=(10,5))
plt.bar(range(len(cv_score)), cv_score)
plt.title('Cross Validation Score')
plt.ylabel('RMSE')
plt.xlabel('Iteration')

plt.plot(range(len(cv_score) + 1), [cv_score.mean()] * (len(cv_score) + 1))
plt.tight_layout()

# %%
'''Testing'''
test_prediction = clf.predict(xTest)
test_prediction
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-27-e7b5832fc0b4> in <module>()
#       1 '''Testing'''
# ----> 2 test_prediction = clf.predict(xTest)
#       3 test_prediction
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in predict(self, X)
#     647         """
#     648         # Check data
# --> 649         X = self._validate_X_predict(X)
#     650
#     651         # Assign chunk of trees to jobs
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in _validate_X_predict(self, X)
#     314         """Validate X whenever one tries to predict, apply, predict_proba"""
#     315         if self.estimators_ is None or len(self.estimators_) == 0:
# --> 316             raise NotFittedError("Estimator not fitted, "
#     317                                  "call `fit` before exploiting the model.")
#     318
#
# NotFittedError: Estimator not fitted, call `fit` before exploiting the model.
