# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
def is_outlier(points, thresh=3.5):
    """
    Returns a boolean array with True if points are outliers and False 
    otherwise.

    Parameters:
    -----------
        points : An numobservations by numdimensions array of observations
        thresh : The modified z-score to use as a threshold. Observations with
            a modified z-score (based on the median absolute deviation) greater
            than this value will be classified as outliers.

    Returns:
    --------
        mask : A numobservations-length boolean array.

    References:
    ----------
        Boris Iglewicz and David Hoaglin (1993), "Volume 16: How to Detect and
        Handle Outliers", The ASQC Basic References in Quality Control:
        Statistical Techniques, Edward F. Mykytka, Ph.D., Editor. 
    """
    if len(points.shape) == 1:
        points = points[:,None]
    median = np.median(points, axis=0)
    diff = np.sum((points - median)**2, axis=-1)
    diff = np.sqrt(diff)
    med_abs_deviation = np.median(diff)

    modified_z_score = 0.6745 * diff / med_abs_deviation

    return modified_z_score > thresh

# %%
train = pd.read_csv(open('train.csv'), sep = ',')
test = pd.read_csv(open('test.csv'), sep = ',')
train.shape, test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
#Scatter plot of Id vs Sale Price
data = train[['Id','SalePrice']].values
#Plot part
plt.scatter(data[:,0],data[:,1]);
plt.xlabel('Id');
plt.ylabel('SalePrice');

# %%
type(train),type(test)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
train.isnull().values.any(),train.isnull().sum().sum()
# Out:
# (True, 6965)

# %%
train.isnull().values.sum().sum()
# Out:
# 6965

# %%
train.shape, test.shape
# Out:
# ((1460, 81), (1459, 80))

# %% [raw]
# for column in (test.loc[:,'MSSubClass':'SaleCondition']).columns:
#     print column + "\t" + str(test[column].isnull().sum())

# %%
for column in (train.loc[:,'MSSubClass':'SaleCondition']).columns:
    if (train[column].isnull().sum() > 80):
        print column + "\t" + str(train[column].isnull().sum())
    else:
        pass
# Out:
# LotFrontage	259
# Alley	1369
# FireplaceQu	690
# GarageType	81
# GarageYrBlt	81
# GarageFinish	81
# GarageQual	81
# GarageCond	81
# PoolQC	1453
# Fence	1179
# MiscFeature	1406

# %%
train.loc[:,'LotFrontage'].isnull().sum(), test.loc[:,'LotFrontage'].isnull().sum()
# Out:
# (259, 227)

# %%
#Concat train and test data so as to avoid mismatch of number of features after applying pandas_dataframe.get_dummies
train_test_data = train.loc[:,'MSSubClass':'SaleCondition']
#train_test_data = pd.concat((train.loc[:,'MSSubClass':'SaleCondition'],test.loc[:,'MSSubClass':'SaleCondition']))
train_test_data.shape
# Out:
# (1460, 79)

# %% [markdown]
# Categorical caolumns

# %%
categorical_columns = []
for column in train_test_data.columns.values:
    if train_test_data[column].dtype == 'object':
        categorical_columns.append(column)

# %%
train_numerical = train_test_data.drop(categorical_columns, axis=1)
test_numerical = test.drop(categorical_columns, axis=1)

train_categorical = train_test_data[categorical_columns]
test_categorical = test[categorical_columns]
train_numerical.columns.values, train_categorical.columns.values
# Out:
# (array(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#         'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#         'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#         '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#         'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#         'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#         'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#         'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#         'MoSold', 'YrSold'], dtype=object),
#  array(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour',
#         'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#         'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#         'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#         'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#         'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
#         'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#         'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#         'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#         'SaleType', 'SaleCondition'], dtype=object))

# %%
test_numerical.columns.values, test_categorical.columns.values
# Out:
# (array(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#         'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#         'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#         '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#         'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#         'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#         'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#         'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#         'MoSold', 'YrSold'], dtype=object),
#  array(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour',
#         'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#         'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#         'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#         'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#         'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
#         'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#         'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#         'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#         'SaleType', 'SaleCondition'], dtype=object))

# %% [markdown]
# Numerical data imputation

# %%
from scipy.stats import skew
from sklearn.preprocessing import Normalizer
dropped_columns = []
for column in train_numerical.columns.values: 
    #print train_numerical[column].isnull().sum()
    if(train_numerical[column].isnull().sum() > 82):
        train_numerical = train_numerical.drop(column, axis = 1)
        print "[%s] column is dropped!" %column
    elif (train_numerical[column].isnull().sum() > 0):
        train_numerical = train_numerical.fillna(train_numerical[column].median())
    
        outlier = np.where(is_outlier(train_numerical[column]))
        train_numerical[column].iloc[outlier] = train_numerical[column].median()
    
        if skew(train_numerical[column]) > 0.75:
            train_numerical[column] = np.log(train_numerical[column])
            train_numerical[column] = train_numerical[column].apply(lambda x: 0 if x == -np.inf else x)
        
        train_numerical[column] = Normalizer().fit_transform(train_numerical[column].reshape(1,-1))[0]
# Out:
# [LotFrontage] column is dropped!

# %%
#Test

for column in test_numerical.columns.values: 
    #print train_numerical[column].isnull().sum()
    if(test_numerical[column].isnull().sum() > 82):
        test_numerical = test_numerical.drop(column, axis = 1)
        print "[%s] column is dropped!" %column
    elif (test_numerical[column].isnull().sum() > 0):
        test_numerical = test_numerical.fillna(test_numerical[column].median())
        """
        outlier = np.where(is_outlier(train_numerical[column]))
        test[column].iloc[outlier] = train_numerical[column].median()
    
        if skew(train_numerical[column]) > 0.75:
            train_numerical[column] = np.log(train_numerical[column])
            train_numerical[column] = train_numerical[column].apply(lambda x: 0 if x == -np.inf else x)
        
        train_numerical[column] = Normalizer().fit_transform(train_numerical[column].reshape(1,-1))[0]
        """
test_numerical = test_numerical.drop('Id', axis = 1)
# Out:
# [LotFrontage] column is dropped!

# %% [markdown]
# Categorical data imputation

# %%
for column in train_categorical.columns.values:
    #print train_categorical[column].isnull().sum()

    if(train_categorical[column].isnull().sum() > 82):
        dropped_columns.append(column)
        train_categorical = train_categorical.drop(column, axis = 1)
        print "[%s] column is dropped !" %column
        continue
    elif (train_categorical[column].isnull().sum() > 0):
        train_categorical[column] = train_categorical.fillna(train_categorical[column].value_counts().index[0])
# Out:
# [Alley] column is dropped !
# [FireplaceQu] column is dropped !
# [PoolQC] column is dropped !
# [Fence] column is dropped !
# [MiscFeature] column is dropped !

# %%
for column in test_categorical.columns.values:
    #print train_categorical[column].isnull().sum()

    if(test_categorical[column].isnull().sum() > 82):
        test_categorical = test_categorical.drop(column, axis = 1)
        print "[%s] column is dropped !" %column
        continue
    elif (test_categorical[column].isnull().sum() > 0):
        test_categorical[column] = test_categorical.fillna(test_categorical[column].value_counts().index[0])
# Out:
# [Alley] column is dropped !
# [FireplaceQu] column is dropped !
# [PoolQC] column is dropped !
# [Fence] column is dropped !
# [MiscFeature] column is dropped !
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
train_numerical.shape, train_categorical.shape, test_numerical.shape, test_categorical.shape
# Out:
# ((1460, 35), (1460, 38), (1459, 36), (1459, 38))

# %%
test = test.drop('Id',axis=1)

# %%
# Out:
# ((1460, 35), (1460, 38), (1459, 79))

# %%
#Convert categorical variable into dummy/indicator variables
train_categorical = pd.get_dummies(train_categorical)
train_categorical.shape
# Out:
# (1460, 237)

# %%
train_test_data_new = train_numerical.join(train_categorical)
train_test_data_new.shape, train_numerical.shape, train_categorical.shape
# Out:
# ((1460, 272), (1460, 35), (1460, 237))

# %%
train_categorical.shape
# Out:
# (1460, 237)

# %%
test = pd.get_dummies(test)

# %%
test.shape
# Out:
# (1459, 73)

# %% [raw]
# trainData
#
# Alley
# FireplaceQu
# GarageCond
# LotFrontage
# PoolQC
# Fence
# MiscFeature
#
# #test data
# testData$Alley<-NULL
# testData$FireplaceQu<-NULL
# testData$PoolQC<-NULL
# testData$Fence<-NULL
# testData$MiscFeature<-NULL
#
# testData$GarageCond<-NULL
# testData$LotFrontage<-NULL

# %%
train_rows = int(train.shape[0] * 0.95)
val_rows = train.shape[0] - train_rows
train_rows, val_rows
# Out:
# (1387, 73)

# %%
#Train partition
xTrain = train_test_data_new.iloc[:train.shape[0],:]
tTrain = train.loc[:train.shape[0] ,'SalePrice']

#xTest partition
xTest = train_test_data_new.iloc[train.shape[0]:,:]

# %%
xTrain.shape, xTest.shape, tTrain.shape
# Out:
# ((1460, 272), (0, 272), (1460,))

# %%
tTrain = pd.DataFrame(np.log1p(tTrain.values))

# %%
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestRegressor

X_train1, X_test1, y_train1, y_test1 = train_test_split(xTrain.values, tTrain.values)
clf = RandomForestRegressor(n_estimators=500, n_jobs=-1)

clf.fit(X_train1, y_train1)
y_pred = clf.predict(X_test1)

y_test1 = y_test1
plt.figure(figsize=(10, 5))
plt.scatter(y_test1, y_pred, s=20)
plt.title('Predicted vs. Actual')
plt.xlabel('Actual Sale Price')
plt.ylabel('Predicted Sale Price')

plt.plot([min(y_test1), max(y_test1)], [min(y_pred), max(y_pred)])
plt.tight_layout()
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
train_test_data_new.shape, xTrain.shape, tTrain.shape, xTest.shape
# Out:
# ((1460, 272), (1460, 272), (1460, 1), (0, 272))

# %% [raw]
# #Random Forest Classifier
# from sklearn.ensemble import RandomForestRegressor
# '''
# The value of n_estimators is kept high so as to have stability of RandomForest;
# If we take lower values of n_estimotros, we'll observe the variation in importance
# of features calculated next.
# '''
# clf = RandomForestRegressor(n_estimators=500, n_jobs=-1)
# clf = clf.fit(xTrain.values,tTrain.values)

# %%
'''Get names of the features of entire data'''
names = list(train_test_data_new.columns.values)
'''Get the feature importance of RandomForest'''
importances = clf.feature_importances_
#print len(importance)

# %% [raw]
# '''Map sorted feature importance and names of features'''
# print "Features sorted by their score:"
# print sorted(zip(map(lambda x: round(x, 4), importances),names),
#              reverse=True)

# %%
sorted_importances = pd.Series(importances, index = train_test_data_new.columns).sort_values(ascending=False)
sorted_importances = pd.Series(sorted_importances)
plt.figure(figsize=(10, 5))
sorted_importances.head(25).plot(kind='bar')
plt.title('Feature Significance')
plt.tight_layout()

# %% [raw]
# '''Validation'''
# val_prediction = clf.predict(vTrain)
# val_prediction.shape
# vtTrain_actual = vtTrain.to_frame().loc[:,'SalePrice'].values
# len(vtTrain_actual), len(val_prediction)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
print "Accuracy", sqrt(mean_squared_error(y_pred, y_test1, multioutput='raw_values'))
# Out:
# Accuracy 0.141870026872

# %% [raw]
# for i in range(len(y_test1)):
#     print str(i) + " :: " + str(y_test1[i]) + " :: " + str(y_pred[i]) + "\n"

# %%
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.cross_validation import cross_val_score

scorer = make_scorer(mean_squared_error, False)

clf = RandomForestRegressor(n_estimators=500)
cv_score = np.sqrt(-cross_val_score(estimator=clf, X=xTrain.values, y=tTrain.values, cv=15, scoring = scorer))

plt.figure(figsize=(10,5))
plt.bar(range(len(cv_score)), cv_score)
plt.title('Cross Validation Score')
plt.ylabel('RMSE')
plt.xlabel('Iteration')

plt.plot(range(len(cv_score) + 1), [cv_score.mean()] * (len(cv_score) + 1))
plt.tight_layout()
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.py:1531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-396-f91417208e1e> in <module>()
#       5
#       6 clf = RandomForestRegressor(n_estimators=500)
# ----> 7 cv_score = np.sqrt(-cross_val_score(estimator=clf, X=xTrain.values, y=tTrain.values, cv=15, scoring = scorer))
#       8
#       9 plt.figure(figsize=(10,5))
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1431                                               train, test, verbose, None,
#    1432                                               fit_params)
# -> 1433                       for train, test in cv)
#    1434     return np.array(scores)[:, 0]
#    1435
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     798             # was dispatched. In particular this covers the edge
#     799             # case of Parallel used with an exhausted iterator.
# --> 800             while self.dispatch_one_batch(iterator):
#     801                 self._iterating = True
#     802             else:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     656                 return False
#     657             else:
# --> 658                 self._dispatch(tasks)
#     659                 return True
#     660
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     564
#     565         if self._pool is None:
# --> 566             job = ImmediateComputeBatch(batch)
#     567             self._jobs.append(job)
#     568             self.n_dispatched_batches += 1
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, batch)
#     178         # Don't delay the application, to avoid keeping the input
#     179         # arguments in memory
# --> 180         self.results = batch()
#     181
#     182     def get(self):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#      70
#      71     def __call__(self):
# ---> 72         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#      73
#      74     def __len__(self):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1529             estimator.fit(X_train, **fit_params)
#    1530         else:
# -> 1531             estimator.fit(X_train, y_train, **fit_params)
#    1532
#    1533     except Exception as e:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in fit(self, X, y, sample_weight)
#     288                     t, self, X, y, sample_weight, i, len(trees),
#     289                     verbose=self.verbose, class_weight=self.class_weight)
# --> 290                 for i, t in enumerate(trees))
#     291
#     292             # Collect newly grown trees
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     798             # was dispatched. In particular this covers the edge
#     799             # case of Parallel used with an exhausted iterator.
# --> 800             while self.dispatch_one_batch(iterator):
#     801                 self._iterating = True
#     802             else:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     656                 return False
#     657             else:
# --> 658                 self._dispatch(tasks)
#     659                 return True
#     660
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     564
#     565         if self._pool is None:
# --> 566             job = ImmediateComputeBatch(batch)
#     567             self._jobs.append(job)
#     568             self.n_dispatched_batches += 1
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __init__(self, batch)
#     178         # Don't delay the application, to avoid keeping the input
#     179         # arguments in memory
# --> 180         self.results = batch()
#     181
#     182     def get(self):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#      70
#      71     def __call__(self):
# ---> 72         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#      73
#      74     def __len__(self):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     114             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     115
# --> 116         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     117     else:
#     118         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     348                                            max_leaf_nodes)
#     349
# --> 350         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     351
#     352         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:
