# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
#!head -2 train.csv

# %%
train = pd.read_csv(open('train.csv'), sep = ',')
test = pd.read_csv(open('test.csv'), sep = ',')

# %%
#Scatter plot of Id vs Sale Price
data = train[['Id','SalePrice']].values
#Plot part
plt.scatter(data[:,0],data[:,1]);
plt.xlabel('Id');
plt.ylabel('SalePrice');

# %%
type(train),type(test)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
train.isnull().values.any(),train.isnull().sum().sum()
# Out:
# (True, 6965)

# %%
#Concat train and test data so as to avoid mismatch of number of features after applying pandas_dataframe.get_dummies
train_test_data = pd.concat((train.loc[:,'MSSubClass':'SaleCondition'],test.loc[:,'MSSubClass':'SaleCondition']))

# %%
#Convert categorical variable into dummy/indicator variables
train_test_data = pd.get_dummies(train_test_data)

# %%
type(train_test_data), type(train)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
train_rows = int(train.shape[0] * 0.8)
val_rows = train.shape[0] - train_rows
train_rows, val_rows
# Out:
# (1168, 292)

# %%
#train_test_data.iloc[:train_rows,:]

# %%
#Train partition
xTrain = train_test_data.iloc[:train_rows,:]
tTrain = train.loc[:train_rows -1 ,'SalePrice']

#Validation partition
vTrain = train_test_data.iloc[train_rows:train.shape[0],:]
vtTrain = train.loc[train_rows:train.shape[0],'SalePrice']

#xTest partition
xTest = train_test_data.iloc[train.shape[0]:,:]

# %%
train_test_data.shape, xTrain.shape, tTrain.shape, vTrain.shape, vtTrain.shape, xTest.shape
# Out:
# ((2919, 288), (1168, 288), (1168,), (292, 288), (292,), (1459, 288))

# %%
'''[Need to rethink on imputation]'''

# Train :filling NA's with the mean of the column 
xTrain = xTrain.fillna(xTrain.mean())
tTrain = tTrain.fillna(tTrain.mean())

# Validation :filling NA's with the mean of the column 
vTrain = vTrain.fillna(vTrain.mean())
vtTrain = vtTrain.fillna(vtTrain.mean())



#Test : filling NA's with the mean of the column:
xTest = xTest.fillna(xTest.mean())

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestRegressor
'''
The value of n_estimators is kept high so as to have stability of RandomForest; 
If we take lower values of n_estimotros, we'll observe the variation in importance 
of features calculated next.
'''
clf = RandomForestRegressor(n_estimators=500)
clf = clf.fit(xTrain,tTrain)

# %%
'''Get names of the features of entire data'''
names = list(train_test_data.columns.values)
'''Get the feature importance of RandomForest'''
importances = clf.feature_importances_
#print len(importance)

# %%
'''Map sorted feature importance and names of features'''
print "Features sorted by their score:"
print sorted(zip(map(lambda x: round(x, 4), importances),names), 
             reverse=True)
# Out:
# Features sorted by their score:
# [(0.5704, 'OverallQual'), (0.1258, 'GrLivArea'), (0.0376, 'TotalBsmtSF'), (0.0302, 'BsmtFinSF1'), (0.0261, '1stFlrSF'), (0.0165, 'GarageArea'), (0.0158, 'GarageCars'), (0.0139, 'LotArea'), (0.0114, 'YearBuilt'), (0.0112, '2ndFlrSF'), (0.0111, 'TotRmsAbvGrd'), (0.008, 'MoSold'), (0.0076, 'YearRemodAdd'), (0.0062, 'LotFrontage'), (0.0056, 'MasVnrArea'), (0.0049, 'FullBath'), (0.0048, 'OpenPorchSF'), (0.0048, 'GarageYrBlt'), (0.0045, 'BsmtUnfSF'), (0.0043, 'WoodDeckSF'), (0.0043, 'OverallCond'), (0.0043, 'BsmtQual_Ex'), (0.0036, 'KitchenQual_Gd'), (0.0034, 'Fireplaces'), (0.0033, 'ExterQual_Ex'), (0.0023, 'BsmtQual_Gd'), (0.0019, 'GarageType_Attchd'), (0.0018, 'YrSold'), (0.0017, 'KitchenQual_Ex'), (0.0017, 'BedroomAbvGr'), (0.0016, 'GarageType_Detchd'), (0.0016, 'BsmtExposure_Gd'), (0.0014, 'LotShape_Reg'), (0.0013, 'CentralAir_Y'), (0.0012, 'ScreenPorch'), (0.0012, 'MSSubClass'), (0.0011, 'MSZoning_RM'), (0.001, 'HalfBath'), (0.001, 'CentralAir_N'), (0.0009, 'KitchenQual_TA'), (0.0009, 'Exterior2nd_HdBoard'), (0.0009, 'BsmtHalfBath'), (0.0009, 'BsmtExposure_No'), (0.0008, 'LotShape_IR2'), (0.0008, 'ExterQual_TA'), (0.0008, 'ExterQual_Gd'), (0.0008, 'EnclosedPorch'), (0.0008, 'BsmtFullBath'), (0.0007, 'SaleType_WD'), (0.0007, 'FireplaceQu_Gd'), (0.0007, 'BsmtFinSF2'), (0.0006, 'Neighborhood_StoneBr'), (0.0006, 'Neighborhood_NoRidge'), (0.0006, 'Neighborhood_Crawfor'), (0.0006, 'MasVnrType_Stone'), (0.0006, 'GarageFinish_Unf'), (0.0006, 'GarageFinish_Fin'), (0.0006, 'BsmtFinType1_GLQ'), (0.0005, 'SaleCondition_Partial'), (0.0005, 'SaleCondition_Normal'), (0.0005, 'RoofStyle_Hip'), (0.0005, 'RoofStyle_Gable'), (0.0005, 'MSZoning_RL'), (0.0005, 'LandContour_Lvl'), (0.0005, 'LandContour_Bnk'), (0.0005, 'GarageFinish_RFn'), (0.0005, 'Exterior2nd_VinylSd'), (0.0005, 'Exterior1st_HdBoard'), (0.0005, 'Condition1_PosN'), (0.0004, 'PavedDrive_N'), (0.0004, 'Neighborhood_Edwards'), (0.0004, 'MasVnrType_BrkFace'), (0.0004, 'MSZoning_C (all)'), (0.0004, 'LotShape_IR1'), (0.0004, 'LotConfig_Inside'), (0.0004, 'LandSlope_Gtl'), (0.0004, 'HeatingQC_Ex'), (0.0004, 'BsmtQual_TA'), (0.0004, 'BsmtFinType1_ALQ'), (0.0003, 'SaleType_New'), (0.0003, 'SaleCondition_Family'), (0.0003, 'PavedDrive_Y'), (0.0003, 'Neighborhood_Timber'), (0.0003, 'Neighborhood_NridgHt'), (0.0003, 'Neighborhood_CollgCr'), (0.0003, 'LotConfig_CulDSac'), (0.0003, 'LotConfig_Corner'), (0.0003, 'LandContour_Low'), (0.0003, 'KitchenAbvGr'), (0.0003, 'HouseStyle_2Story'), (0.0003, 'HeatingQC_TA'), (0.0003, 'GarageType_BuiltIn'), (0.0003, 'GarageQual_TA'), (0.0003, 'Functional_Typ'), (0.0003, 'Foundation_PConc'), (0.0003, 'FireplaceQu_Ex'), (0.0003, 'Exterior1st_VinylSd'), (0.0003, 'Condition2_Norm'), (0.0003, 'Condition1_Norm'), (0.0002, 'SaleCondition_Abnorml'), (0.0002, 'Neighborhood_OldTown'), (0.0002, 'Neighborhood_NAmes'), (0.0002, 'Neighborhood_ClearCr'), (0.0002, 'MasVnrType_None'), (0.0002, 'LandSlope_Mod'), (0.0002, 'LandContour_HLS'), (0.0002, 'HouseStyle_1Story'), (0.0002, 'HouseStyle_1.5Fin'), (0.0002, 'HeatingQC_Gd'), (0.0002, 'Foundation_CBlock'), (0.0002, 'FireplaceQu_TA'), (0.0002, 'Exterior2nd_MetalSd'), (0.0002, 'Exterior1st_Wd Sdng'), (0.0002, 'Exterior1st_MetalSd'), (0.0002, 'Exterior1st_CemntBd'), (0.0002, 'Exterior1st_BrkFace'), (0.0002, 'ExterCond_TA'), (0.0002, 'ExterCond_Fa'), (0.0002, 'BsmtFinType1_Unf'), (0.0002, 'BsmtExposure_Av'), (0.0002, 'BsmtCond_Gd'), (0.0002, 'BldgType_1Fam'), (0.0001, 'SaleType_COD'), (0.0001, 'RoofStyle_Flat'), (0.0001, 'RoofMatl_CompShg'), (0.0001, 'Neighborhood_Somerst'), (0.0001, 'Neighborhood_SawyerW'), (0.0001, 'Neighborhood_Sawyer'), (0.0001, 'Neighborhood_NWAmes'), (0.0001, 'Neighborhood_IDOTRR'), (0.0001, 'Neighborhood_Gilbert'), (0.0001, 'Neighborhood_BrkSide'), (0.0001, 'MSZoning_FV'), (0.0001, 'LowQualFinSF'), (0.0001, 'LotConfig_FR2'), (0.0001, 'KitchenQual_Fa'), (0.0001, 'HeatingQC_Fa'), (0.0001, 'GarageCond_TA'), (0.0001, 'Functional_Mod'), (0.0001, 'Foundation_BrkTil'), (0.0001, 'Fence_MnPrv'), (0.0001, 'Fence_GdW ...

# %%
'''Plot feature names vs feature importance importances = clf.feature_importances_'''

indices = np.argsort(importances)[::-1]

'''Print the feature ranking'''
print("Feature ranking:")

'''
for f in range(xTrain.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

for f in range(xTrain.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
'''

'''Plot the feature importances of the forest'''
plt.figure()
plt.title("Feature importances")
plt.bar(range(xTrain.shape[1]), importances[indices],
       color="b", align="center")
plt.xticks(range(xTrain.shape[1]), indices)
plt.xlim([-1, xTrain.shape[1]*0.05])
plt.show()
# Out:
# Feature ranking:

# %%
'''Validation'''
val_prediction = clf.predict(vTrain)
val_prediction.shape
# Out:
# (292,)

# %%
vtTrain_actual = vtTrain.to_frame().loc[:,'SalePrice'].values
len(vtTrain_actual), len(val_prediction)
# Out:
# (292, 292)

# %%
type(vtTrain_actual), type(val_prediction)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
vtTrain_actual.shape, val_prediction.shape
# Out:
# ((292,), (292,))

# %%
plt.figure(figsize=(10, 5))
plt.scatter(vtTrain_actual, val_prediction, s=20)
plt.title('Predicted vs. Actual')
plt.xlabel('Actual Sale Price')
plt.ylabel('Predicted Sale Price')

plt.plot([min(vtTrain_actual), max(vtTrain_actual)], [min(vtTrain_actual), max(vtTrain_actual)])
plt.tight_layout()

# %%
'''Accuracy score'''
'''
from sklearn.metrics import accuracy_score
print "Accuracy", accuracy_score(vtTrain_actual, val_prediction)
'''
# Out:
# '\nfrom sklearn.metrics import accuracy_score\nprint "Accuracy", accuracy_score(vtTrain_actual, val_prediction)\n'

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
print "Accuracy", sqrt(mean_squared_error(val_prediction, vtTrain_actual, multioutput='raw_values'))
# Out:
# Accuracy 35765.78249

# %%
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.cross_validation import cross_val_score

scorer = make_scorer(mean_squared_error, False)

clf = RandomForestRegressor(n_estimators=500, n_jobs=-1)
cv_score = np.sqrt(-cross_val_score(estimator=clf, X=xTrain, y=tTrain, cv=15, scoring = scorer))

plt.figure(figsize=(10,5))
plt.bar(range(len(cv_score)), cv_score)
plt.title('Cross Validation Score')
plt.ylabel('RMSE')
plt.xlabel('Iteration')

plt.plot(range(len(cv_score) + 1), [cv_score.mean()] * (len(cv_score) + 1))
plt.tight_layout()

# %%
'''Testing'''
test_prediction = clf.predict(xTest)
test_prediction
